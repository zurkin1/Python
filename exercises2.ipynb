# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h1>תרגילים - רמה 2 (בינוני)</h1>
# <p>תרגילים המשלבים תנאים מרובים (elif), אופרטור and, מונים וצוברים בתוך לולאות, ולולאות עם step.</p>
# <p>לכל תרגיל מופיע הסבר, ולאחריו תא קוד. כתבו את הפתרון שלכם בתא הקוד והריצו אותו כדי לבדוק שהוא עובד כמו שצריך.</p>
# </div>

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 1: המספר הגדול מבין שלושה</h3>
# <p>בקשו מהמשתמש להזין 3 מספרים, ומצאו והדפיסו את הגדול מביניהם (השתמשו ב- if / elif / else).</p>
# </div>

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 2: ציון באותיות</h3>
# <p>בקשו ציון (0-100), והדפיסו את ציון האותיות המתאים לפי הטבלה. שימו לב לסדר הנכון של התנאים בשרשרת elif:</p><ul><li>90 ומעלה - A</li><li>80-89 - B</li><li>70-79 - C</li><li>60-69 - D</li><li>מתחת ל-60 - F</li></ul>
# </div>

# %%
grade = int(input("Enter your grade: "))

# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 3: מתחלק גם ב-3 וגם ב-5</h3>
# <p>בקשו מהמשתמש מספר שלם, ובדקו האם הוא מתחלק גם ב-3 וגם ב-5 (השתמשו ב- and). הדפיסו הודעה מתאימה.</p>
# </div>

# %%
num = int(input("Enter a number: "))

# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 4: שנה מעוברת</h3>
# <p>בקשו מהמשתמש שנה (year), ובדקו האם היא שנה מעוברת (leap year). שנה מעוברת היא שנה שמתחלקת ב-4, אך אם היא מתחלקת גם ב-100 היא <b>לא</b> מעוברת - אלא אם היא מתחלקת גם ב-400.</p><p><i>רמז: year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)</i></p>
# </div>

# %%
year = int(input("Enter a year: "))

# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 5: סכום 1 עד 100</h3>
# <p>חשבו וסכמו בעזרת לולאה את כל המספרים מ-1 עד 100 (כלומר 1+2+3+...+100), והדפיסו את הסכום הסופי בלבד.</p>
# </div>

# %%
# כתבו כאן את הפתרון (השתמשו במשתנה צובר)

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 6: סכום מספרים זוגיים</h3>
# <p>חשבו וסכמו בעזרת לולאה את כל המספרים הזוגיים בין 1 ל-50, והדפיסו את הסכום.</p>
# </div>

# %%
# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 7: כמה מספרים מתחלקים ב-7</h3>
# <p>ספרו כמה מספרים בין 1 ל-100 מתחלקים ב-7 (בעזרת לולאה ומונה), והדפיסו את הכמות.</p>
# </div>

# %%
# כתבו כאן את הפתרון (השתמשו במשתנה מונה)

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 8: ממוצע 5 מספרים</h3>
# <p>בקשו מהמשתמש להזין 5 מספרים (בעזרת לולאה), וחשבו והדפיסו את הממוצע שלהם.</p>
# </div>

# %%
# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 9: מספרים אי-זוגיים</h3>
# <p>הדפיסו בעזרת לולאה עם step את כל המספרים האי-זוגיים בין 1 ל-20.</p><p><i>רמז: range(1, 21, 2)</i></p>
# </div>

# %%
# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 10: ספירה לאחור</h3>
# <p>הדפיסו בעזרת לולאה ספירה לאחור מ-10 עד 1, ולאחר סיום הלולאה הדפיסו "Liftoff!"</p>
# </div>

# %%
# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 11: חישוב שכר עם שעות נוספות</h3>
# <p>בקשו ממשתמש כמות שעות עבודה (hours) ושכר לשעה (rate). אם עבד עד 40 שעות - השכר הוא hours*rate. אם עבד יותר מ-40 שעות, השעות הנוספות משולמות פי 1.5 מהשכר הרגיל. חשבו והדפיסו את השכר הכולל.</p>
# </div>

# %%
hours = float(input("Enter hours worked: "))
rate = float(input("Enter hourly rate: "))

# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 12: לוח הכפל של 7</h3>
# <p>הדפיסו בעזרת לולאה את לוח הכפל של המספר 7 (7 כפול 1 עד 7 כפול 10), בפורמט: <code>7 x 1 = 7</code></p>
# </div>

# %%
# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 13: Fizz</h3>
# <p>הדפיסו בעזרת לולאה את המספרים מ-1 עד 30. עבור מספרים שמתחלקים ב-3, הדפיסו "Fizz" במקום המספר.</p>
# </div>

# %%
# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 14: בדיקת סיסמה</h3>
# <p>נתון משתנה password. בקשו מהמשתמש להזין סיסמה, ואם היא תואמת - הדפיסו "הכניסה אושרה", אחרת - "הכניסה נדחתה".</p>
# </div>

# %%
password = "1234"
entered = input("Enter password: ")

# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 15: ספירת מספרים חיוביים</h3>
# <p>בקשו מהמשתמש להזין 10 מספרים (בעזרת לולאה), וספרו כמה מהם חיוביים.</p>
# </div>

# %%
# כתבו כאן את הפתרון (השתמשו במשתנה מונה)

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 16: סכום מספרים שליליים</h3>
# <p>בקשו מהמשתמש להזין 10 מספרים (בעזרת לולאה), וחשבו את סכום המספרים השליליים בלבד.</p>
# </div>

# %%
# כתבו כאן את הפתרון (השתמשו במשתנה צובר)
