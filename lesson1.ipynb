# %% [markdown]
# <div style="text-align: right;" dir="rtl">
#
# <h2>מה נלמד השנה</h2>
# <ul>
# <li><p>השיעור הראשון מוקדש להיכרות ומה מצפה לנו השנה</p></li>
# <li><p>בנוסף לספריית pygame  נלמד גם את נושא תכנות מונחה עצמים והורשה, מה שיאפשר לנו לפתח משחקים מורכבים ויצירתיים יותר, וכמובן יפתח את היכולות וההבנה שלנו במדעי מחשב</p></li>
# <li><p>בנוסף נלמד לעבוד נכון על מחוללי שפה (Gemini, ChatGPT ועוד), כיצד להשתמש בהם כך שיהיה לנו יותר קל ופשוט ללמוד, אך עדיין תהליך הלמידה וההבנה שלו לא ייפגעו</p></li>
# <li><p>במהלך השנה נלמד לשלב את ספריית genai בקוד , מה שיאפשר לנו לגשת ל gemini  תוך כדי ריצה ולכתוב משחקים כמו אליאס, טריויה וכו'</p></li>
# <li><p>את שני השיעורים הראשונים כדאי להקדיש לחזרה על היסודות משנה שעברה (התלמידים לא זוכרים ).</p></li>
# <li><p>וכמובן להציג את מצגת השימוש הנכון בבינה מלאכותית</p></li>
# </ul>
#
# </div>

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <details>
#   <summary style="text-align: right; direction: rtl;"><h2>מה נלמד היום</h2></summary>
#   <div>
#   <ul style="text-align: right; direction: rtl;">
#   <li>הוראות הדפסה למסך</li>
#   <li>חשיפה להוראת קלט</li>
#   <li>סכמה של קלט פלט</li>
#   <li>קלט מטיפוס מחרוזת (טקסט)</li>
#   <li>קלט מטיפוס מספר</li>
#   <li>תרגול חישובים פשוטים וגרפיקה פשוטה</li>
#   </ul>
#   </div>
# </details>
# </div>

# %%
# הערה כותבים באמצעות התו "#"

# %%
# Input
print("Hello World")

# %%
# Output
name = input("What is your name? ")
print(name, "nice to meet you.")

# %%
# Simple printing
print("********")
print(" ****** ")
print("  ****  ")
print("   **   ")

# %%
# Calculations
'''
+ חיבור
- חיסור
/ חילוק
* כפל
** חזקה
'''
print(1+2)
print(1-2)
print(1*2)
print(4/2)
print(2**3)

# %%
# הריצו את הקוד הבא ובדקו מה מבצעת הפקודה:
print ("Hello "*3)

#print ("Hello "*3, end = "\n")

#print ("Hello "*3, end = "*")

# %%
# מה יודפס פה?
print(1,2,3)
print(1-2, 5*6, 7+8)
print(5>6)
print("My age is:", 13)
print(2,5,6, end="*")

# %%
# מה יודפס במקרים הבאים הבאים?
print(input("What is your name: "))

# %%
print("My name is: ", input("What is your name: "))

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <right>
# <p dir="rtl">נסכם:</p>
# <p dir="rtl">בתכנות קולטים מהמשתמש קלט -</p>
# <p dir="rtl">- העובר עיבוד ולאחר מכן</p>
# <p dir="rtl">- מודפס או נשמר לשימוש עתידי.</p>
# <p dir="rtl">כיצד שומרים את הקלט?</p>
# <p dir="rtl">על כך נלמד בפרק הבא ☺</p>
# </right>
# </div>
