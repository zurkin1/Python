# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h1>תרגילים - רמה 3 (קשה)</h1>
# <p>תרגילים מאתגרים המשלבים לולאות מקוננות, עבודה עם ספרות של מספר, מציאת מינימום/מקסימום, ותנאים מורכבים. חלק מהתרגילים כוללים רמז לגבי הדרך לפתור אותם.</p>
# <p>לכל תרגיל מופיע הסבר, ולאחריו תא קוד. כתבו את הפתרון שלכם בתא הקוד והריצו אותו כדי לבדוק שהוא עובד כמו שצריך.</p>
# </div>

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 1: FizzBuzz</h3>
# <p>הדפיסו בעזרת לולאה את המספרים מ-1 עד 30. עבור מספרים שמתחלקים גם ב-3 וגם ב-5 הדפיסו "FizzBuzz", עבור מספרים שמתחלקים ב-3 בלבד הדפיסו "Fizz", עבור מספרים שמתחלקים ב-5 בלבד הדפיסו "Buzz", ואחרת הדפיסו את המספר עצמו.</p>
# </div>

# %%
# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 2: בדיקת מספר ראשוני</h3>
# <p>בקשו מהמשתמש מספר שלם n (גדול מ-1), ובדקו האם הוא ראשוני (prime) - מספר שמתחלק רק ב-1 ובעצמו.</p><p><i>רמז: השתמשו במשתנה בוליאני is_prime שמתחיל כ- True, ובדקו בלולאה על המספרים בין 2 ל- n-1 האם n מתחלק באחד מהם. אם כן - שנו את is_prime ל- False.</i></p>
# </div>

# %%
n = int(input("Enter a number greater than 1: "))

# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 3: סכום ספרות של מספר</h3>
# <p>בקשו מהמשתמש מספר, וחשבו את סכום הספרות שלו (גם אם יש בו יותר משתי ספרות).</p><p><i>רמז: המירו את המספר למחרוזת בעזרת str(num), ולאחר מכן עברו על כל תו בלולאה (for digit in str(num):) והמירו כל תו בחזרה למספר בעזרת int(digit).</i></p>
# </div>

# %%
num = int(input("Enter a number: "))

# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 4: היפוך מספר</h3>
# <p>בקשו מהמשתמש מספר, והדפיסו אותו הפוך (כלומר, הספרות בסדר הפוך). לדוגמה: 1234 &#8592; 4321.</p><p><i>רמז: התחילו ממחרוזת ריקה בשם reversed_num, ובלולאה על ספרות המספר (כמו בתרגיל הקודם) הוסיפו כל ספרה <b>בתחילת</b> המחרוזת: reversed_num = digit + reversed_num</i></p>
# </div>

# %%
num = int(input("Enter a number: "))

# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 5: משולש כוכביות</h3>
# <p>הדפיסו בעזרת לולאה משולש של כוכביות - בשורה הראשונה כוכבית אחת, בשנייה שתיים, וכן הלאה, עד 5 שורות:</p><pre dir="ltr" style="text-align: left;">*
# **
# ***
# ****
# *****</pre><p><i>רמז: בכל סיבוב חיצוני (שורה), הריצו לולאה פנימית שמדפיסה כוכביות בלי מעבר שורה (end=""), ובסוף השורה הדפיסו מעבר שורה ריק.</i></p>
# </div>

# %%
# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 6: לוח כפל מלא</h3>
# <p>הדפיסו לוח כפל מלא מ-1 עד 10 (10x10), בעזרת שתי לולאות מקוננות.</p>
# </div>

# %%
# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 7: ספירת תנועות במילה</h3>
# <p>נתון משתנה word ששומר מילה. ספרו כמה תנועות (a, e, i, o, u) יש במילה, בעזרת לולאה שעוברת על כל אות במילה (for ch in word:).</p>
# </div>

# %%
word = "programming"

# כתבו כאן את הפתרון (השתמשו במשתנה מונה)

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 8: מציאת המקסימום</h3>
# <p>בקשו מהמשתמש להזין 5 מספרים (בעזרת לולאה), ומצאו והדפיסו את המספר הגדול ביותר מביניהם - <b>בלי</b> להשתמש בפונקציה max().</p><p><i>רמז: שמרו משתנה largest שמתחיל בערך המספר הראשון שהוזן, ובכל סיבוב השוו אליו את המספר החדש.</i></p>
# </div>

# %%
# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 9: מציאת המינימום</h3>
# <p>בקשו מהמשתמש להזין 5 מספרים, ומצאו והדפיסו את המספר הקטן ביותר מביניהם - <b>בלי</b> להשתמש בפונקציה min().</p>
# </div>

# %%
# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 10: עצרת (Factorial)</h3>
# <p>חשבו את העצרת (factorial) של מספר n שהמשתמש מזין. (n! = 1*2*3*...*n. לדוגמה: 5! = 1*2*3*4*5 = 120)</p><p><i>רמז: השתמשו במשתנה צובר שנקרא result, שמתחיל בערך 1 ומוכפל בכל סיבוב לולאה.</i></p>
# </div>

# %%
n = int(input("Enter a number: "))

# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 11: משחק ניחושים עם ניסיונות מוגבלים</h3>
# <p>המחשב בוחר מספר אקראי בין 1 ל-10 (בעזרת random.randint), ולמשתמש יש 3 ניסיונות לנחש אותו. בכל ניסיון בדקו ותדפיסו האם הניחוש היה נכון, גדול מדי, או קטן מדי.</p>
# </div>

# %%
import random

comp_num = random.randint(1, 10)

# כתבו כאן קוד עם לולאה של 3 ניסיונות

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 12: בדיקת משולש תקין</h3>
# <p>בקשו מהמשתמש להזין 3 אורכי צלעות של משולש. בדקו האם ניתן לבנות מהם משולש תקין - כלל: כל צלע חייבת להיות קטנה מסכום שתי הצלעות האחרות.</p>
# </div>

# %%
side1 = float(input("Enter side 1: "))
side2 = float(input("Enter side 2: "))
side3 = float(input("Enter side 3: "))

# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 13: פירמידה ממורכזת</h3>
# <p>הדפיסו בעזרת לולאות מקוננות פירמידה של כוכביות עם רווחים, כך שתהיה ממורכזת (5 שורות):</p><pre dir="ltr" style="text-align: left;">    *
#    ***
#   *****
#  *******
# *********</pre><p><i>רמז: בכל שורה, מספר הרווחים בתחילת השורה פוחת ב-1, ומספר הכוכביות עולה ב-2.</i></p>
# </div>

# %%
# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 14: סיווג מספרים</h3>
# <p>בקשו מהמשתמש להזין 10 מספרים (בעזרת לולאה), וסווגו כל מספר כחיובי, שלילי או אפס. בסיום, הדפיסו כמה מספרים היו מכל סוג.</p>
# </div>

# %%
# כתבו כאן את הפתרון (השתמשו בשלושה משתני מונה)

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 15: מעל הממוצע</h3>
# <p>בקשו מהמשתמש להזין 5 מספרים (בעזרת לולאה), וחשבו את הממוצע שלהם. לאחר מכן, בקשו מהמשתמש להזין את אותם 5 מספרים בשנית, וספרו כמה מהם היו מעל הממוצע שחישבתם.</p><p><i>רמז: תצטרכו שתי לולאות נפרדות - אחת לחישוב הסכום והממוצע, ואחת שנייה להשוואה מול הממוצע.</i></p>
# </div>

# %%
# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 16: ריבוע כוכביות</h3>
# <p>בקשו מהמשתמש מספר n, והדפיסו בעזרת לולאה מקוננת ריבוע בגודל n x n העשוי מכוכביות.</p>
# </div>

# %%
n = int(input("Enter n: "))

# כתבו כאן את הפתרון

# %% [markdown]
# <div style="text-align: right;" dir="rtl">
# <h3>תרגיל 17: מספר מושלם</h3>
# <p>בדקו האם מספר הוא "מספר מושלם" (perfect number) - מספר ששווה לסכום המחלקים שלו (לא כולל את עצמו). לדוגמה: 6 מושלם כי 6 = 1+2+3.</p><p><i>רמז: עברו בלולאה על כל המספרים בין 1 ל- n-1, ובדקו בעזרת % האם כל אחד מהם מחלק את n. אם כן - הוסיפו אותו למשתנה צובר.</i></p>
# </div>

# %%
n = int(input("Enter a number: "))

# כתבו כאן את הפתרון
